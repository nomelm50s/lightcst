# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('LightStatus.csv')

# %%
data
# Out:
#        na  State              Name                Date
# 0   ["xx"      0      Front Lights  22/01/20T08:08:22]
# 1   ["xx"      0  Back Yard Lights  22/01/20T08:08:22]
# 2   ["xx"      0  Back Yard Lights  22/01/20T08:09:20]
# 3   ["xx"      0      Front Lights  22/01/20T08:09:21]
# 4   ["xx"      0      Front Lights  22/01/20T08:10:21]
# 5   ["xx"      0  Back Yard Lights  22/01/20T08:10:21]
# 6   ["xx"      0      Front Lights  22/01/20T08:11:21]
# 7   ["xx"      0  Back Yard Lights  22/01/20T08:11:21]
# 8   ["xx"      0      Front Lights  22/01/20T08:12:21]
# 9   ["xx"      0  Back Yard Lights  22/01/20T08:12:21]
# 10  ["xx"      0      Front Lights  22/01/20T08:13:20]
# 11  ["xx"      0  Back Yard Lights  22/01/20T08:13:21]
# 12  ["xx"      0      Front Lights  22/01/20T08:14:14]
# 13  ["xx"      0  Back Yard Lights  22/01/20T08:14:14]
# 14  ["xx"      0  Back Yard Lights  22/01/20T08:15:13]
# 15  ["xx"      0      Front Lights  22/01/20T08:15:13]
# ...

# %%
dates = data['Date']

# %%
dates
# Out:
# 0     22/01/20T08:08:22]
# 1     22/01/20T08:08:22]
# 2     22/01/20T08:09:20]
# 3     22/01/20T08:09:21]
# 4     22/01/20T08:10:21]
# 5     22/01/20T08:10:21]
# 6     22/01/20T08:11:21]
# 7     22/01/20T08:11:21]
# 8     22/01/20T08:12:21]
# 9     22/01/20T08:12:21]
# 10    22/01/20T08:13:20]
# 11    22/01/20T08:13:21]
# 12    22/01/20T08:14:14]
# 13    22/01/20T08:14:14]
# 14    22/01/20T08:15:13]
# 15    22/01/20T08:15:13]
# 16    22/01/20T08:16:13]
# 17    22/01/20T08:16:13]
# 18    22/01/20T08:17:13]
# 19    22/01/20T08:17:13]
# 20    22/01/20T08:18:13]
# 21    22/01/20T08:18:13]
# 22    22/01/20T08:19:13]
# 23    22/01/20T08:19:13]
# 24    22/01/20T08:20:13]
# 25    22/01/20T08:20:13]
# 26    22/01/20T08:21:13]
# 27    22/01/20T08:21:13]
# 28    22/01/20T08:22:13]
# 29    22/01/20T08:22:13]
# Name: Date, dtype: object

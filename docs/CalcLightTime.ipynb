# %% [markdown]
# NOTE: This notebook contains the code fragements developed while testing various methods of performing math with the datetime object. It does not reflect the final build of the getontimes() function that was the product of this exercise. See the calclighttime.py module for the final product.

# %% [markdown]
# # CalcLightTime.py
#
# The code and comments listed below contain the instructions used to extract the date and time values out of a csv file using a Pandas data frame. The CSV file is created and updated by a Node-RED flow that automatically turns the outside lights on and off at sun set and sun rise.

# %% [markdown]
# ## getontimes()
#
# The on and off times of the networked attached switches and calculates the time on using Python datetime object.

# %%
import datetime
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/mikee/projects/lightcst/data/LightStatus.csv') # reads the csv file into a Pandas Data Frame.

# %%
dt = df['Date'] # Get a copy of the Date/Time column as a list of strings

# %%
format = '%y/%m/%dT%H:%M:%S]' # The date format used to convert to a date/time object

# %% [markdown]
# The next 2 lines of code convert the date/time string values to days hours and seconds since since December 30, 1899. Math operations can be performed on the objects.

# %%
dtstart = datetime.datetime.strptime(dt[1], format)
dtstart
# Out:
# datetime.datetime(2022, 1, 20, 8, 8, 22)

# %%
dtend = datetime.datetime.strptime(dt[20], format)
dtend
# Out:
# datetime.datetime(2022, 1, 20, 8, 18, 13)

# %%
dtdelta = dtend - dtstart

# %%
dtdelta
# Out:
# datetime.timedelta(seconds=591)

# %% [markdown]
# ## Find on time

# %%
df
# Out:
#           na  State              Name                Date
# 0      ["xx"      0      Front Lights  22/01/20T08:08:22]
# 1      ["xx"      0  Back Yard Lights  22/01/20T08:08:22]
# 2      ["xx"      0  Back Yard Lights  22/01/20T08:09:20]
# 3      ["xx"      0      Front Lights  22/01/20T08:09:21]
# 4      ["xx"      0      Front Lights  22/01/20T08:10:21]
# ...      ...    ...               ...                 ...
# 31782  ["xx"      0      Front Lights  22/02/07T12:24:51]
# 31783  ["xx"      0      Front Lights  22/02/07T12:26:51]
# 31784  ["xx"      0      Front Lights  22/02/07T12:29:51]
# 31785  ["xx"      0      Front Lights  22/02/07T12:32:51]
# 31786  ["xx"      0      Front Lights  22/02/07T12:35:51]
#
# [31787 rows x 4 columns]

# %%
p_row = 0
tms = []

# %%
for index, row in df.iterrows():
    if row['State'] == 1 & p_row == 0:
        if row['Name'] == 'Front Lights':
            frow = ['Start', row['Date'], row['Name'], row['State']]
            p_row = row['State']
            tms.append(frow)
        p_row = row['State']

print(tms)
# Out:
# [['Start', '22/01/20T08:08:22]', 'Front Lights', 0], ['Start', '22/01/20T08:09:21]', 'Front Lights', 0], ['Start', '22/01/20T08:10:21]', 'Front Lights', 0], ['Start', '22/01/20T08:11:21]', 'Front Lights', 0], ['Start', '22/01/20T08:12:21]', 'Front Lights', 0], ['Start', '22/01/20T08:13:20]', 'Front Lights', 0], ['Start', '22/01/20T08:14:14]', 'Front Lights', 0], ['Start', '22/01/20T08:15:13]', 'Front Lights', 0], ['Start', '22/01/20T08:16:13]', 'Front Lights', 0], ['Start', '22/01/20T08:17:13]', 'Front Lights', 0], ['Start', '22/01/20T08:18:13]', 'Front Lights', 0], ['Start', '22/01/20T08:19:13]', 'Front Lights', 0], ['Start', '22/01/20T08:20:13]', 'Front Lights', 0], ['Start', '22/01/20T08:21:13]', 'Front Lights', 0], ['Start', '22/01/20T08:22:13]', 'Front Lights', 0], ['Start', '22/01/20T08:23:13]', 'Front Lights', 0], ['Start', '22/01/20T08:24:13]', 'Front Lights', 0], ['Start', '22/01/20T08:25:13]', 'Front Lights', 0], ['Start', '22/01/20T08:26:13]', 'Front Lights', 0], ['Start', '22/01/20T08:27:13]', 'Front Lights', 0], ['Start', '22/01/20T08:28:13]', 'Front Lights', 0], ['Start', '22/01/20T08:29:13]', 'Front Lights', 0], ['Start', '22/01/20T08:30:13]', 'Front Lights', 0], ['Start', '22/01/20T08:31:13]', 'Front Lights', 0], ['Start', '22/01/20T08:32:13]', 'Front Lights', 0], ['Start', '22/01/20T08:33:13]', 'Front Lights', 0], ['Start', '22/01/20T08:34:13]', 'Front Lights', 0], ['Start', '22/01/20T08:35:13]', 'Front Lights', 0], ['Start', '22/01/20T08:36:13]', 'Front Lights', 0], ['Start', '22/01/20T08:37:13]', 'Front Lights', 0], ['Start', '22/01/20T08:38:13]', 'Front Lights', 0], ['Start', '22/01/20T08:39:13]', 'Front Lights', 0], ['Start', '22/01/20T08:40:13]', 'Front Lights', 0], ['Start', '22/01/20T08:41:13]', 'Front Lights', 0], ['Start', '22/01/20T08:42:13]', 'Front Lights', 0], ['Start', '22/01/20T08:43:13]', 'Front Lights', 0], ['Start', '22/01/20T08:44:13]', 'Front Lights', 0], ['Start', '22/01/20T08:45:13]', 'Front Lights', 0], ['Start', '22/01/20T08:46:13]', 'Front Lights', 0], ['Start', '22/01/20T08:47:13]', 'Front Lights', 0], ['Start', '22/01/20T08:48:13]', 'Front Lights', 0], ['Start', '22/01/20T08:49:13]', 'Front Lights', 0], ['Start', '22/01/20T08:50:13]', 'Front Lights', 0], ['Start', '22/01/20T08:51:13]', 'Front Lights', 0], ['Start', '22/01/20T08:52:13]', 'Front Lights', 0], ['Start', '22/01/20T08:53:13]', 'Front Lights', 0], ['Start', '22/01/20T08:54:13]', 'Front Lights', 0], ['Start', '22/01/20T08:55:13]', 'Front Lights', 0], ['Start', '22/01/20T08:56:13]', 'Front Lights', 0], ['Start', '22/01/20T08:57:13]', 'Front Lights', 0], ['Start', '22/01/20T08:58:13]', 'Front Lights', 0], ['Start', '22/01/20T08:59:13]', 'Front Lights', 0], ['Start', '22/01/20T09:00:13]', 'Front Lights', 0], ['Start', '22/01/20T09:01:13]', 'Front Lights', 0], ['Start', '22/01/20T09:02:13]', 'Front Lights', 0], ['Start', '22/01/20T09:03:13]', 'Front Lights', 0], ['Start', '22/01/20T09:04:13]', 'Front Lights', 0], ['Start', '22/01/20T09:05:13]', 'Front Lights', 0], ['Start', '22/01/20T09:06:13]', 'Front Lights', 0], ['Start', '22/01/20T09:07:13]', 'Front Lights', 0], ['Start', '22/01/20T09:08:13]', 'Front Lights', 0], ['Start', '22/01/20T09:09:13]', 'Front Lights', 0], ['Start', '22/01/20T09:10:13]', 'Front Lights', 0], ['Start', '22/01/20T09:11:13]', 'Front Lights', 0], ['Start', '22/01/20T09:12:13]', 'Front Lights', 0], ['Start', '22/01/20T09:13:13]', 'Front Lights', 0], ['Start', '22/01/20T09:14:13]', 'Front Lights', 0], ['Start', '22/01/20T09:15:13]', 'Front Lights', 0], ['Start', '22/01/20T09:16:13]', 'Front Lights', 0], ['Start', '22/01/20T09:17:13]', 'Front Lights', 0], ['Start', '22/01/20T09:18:13]', 'Front Lights', 0], ['Start', '22/01/20T09:19:13]', 'Front Lights', 0], ['Start', '22/01/20T09:20:13]', 'Front Lights', 0], ['Start', '22/01/20T09:21:13]', 'Front Lights', 0], ['Start', '22/01/20T09:22:13]', 'Front Lights', 0], ['Start', '22/01/20T09:23:13]', 'Front Lights', 0], ['Start', '22/01/20T09:24:13]', 'Front Lights', ...

# %%
len(tms)
# Out:
# 5044
